# %% [markdown]
# # Red Wine Quality Prediction

# %%
# Importing required libraries

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %%
# Loading the dataset

df = pd.read_csv('winequality-red.csv')
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                  34.0   0.9978  3.51       0.56
# 1                 25.0                  67.0   0.9968  3.20       0.68
# 2                 15.0                  54.0   0.9970  3.26       0.65
# 3                 17.0                  60.0   0.9980  3.16       0.58
# 4                 11.0                  34.0   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
# checking the data dimension i.e., number of rows and columns

df.shape
# Out:
# (1599, 12)

# %%
# checking the datatype of every column

df.dtypes
# Out:
# fixed acidity           float64
# volatile acidity        float64
# citric acid             float64
# residual sugar          float64
# chlorides               float64
# free sulfur dioxide     float64
# total sulfur dioxide    float64
# density                 float64
# pH                      float64
# sulphates               float64
# alcohol                 float64
# quality                   int64
# dtype: object

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# checking for null values

df.isnull().sum()
# Out:
# fixed acidity           0
# volatile acidity        0
# citric acid             0
# residual sugar          0
# chlorides               0
# free sulfur dioxide     0
# total sulfur dioxide    0
# density                 0
# pH                      0
# sulphates               0
# alcohol                 0
# quality                 0
# dtype: int64

# %% [raw]
# There are no missing values in any column, so need of handling missing data.

# %%
df.shape
# Out:
# (1599, 12)

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  citric acid  residual sugar  \
# count    1599.000000       1599.000000  1599.000000     1599.000000
# mean        8.319637          0.527821     0.270976        2.538806
# std         1.741096          0.179060     0.194801        1.409928
# min         4.600000          0.120000     0.000000        0.900000
# 25%         7.100000          0.390000     0.090000        1.900000
# 50%         7.900000          0.520000     0.260000        2.200000
# 75%         9.200000          0.640000     0.420000        2.600000
# max        15.900000          1.580000     1.000000       15.500000
#
#          chlorides  free sulfur dioxide  total sulfur dioxide      density  \
# count  1599.000000          1599.000000           1599.000000  1599.000000
# mean      0.087467            15.874922             46.467792     0.996747
# std       0.047065            10.460157             32.895324     0.001887
# ...

# %% [markdown]
# # EDA (Data Visualization and Analysis)

# %%
df['quality'].unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
# Frequency of the wine quality classes
plt.figure(figsize = (10,5))
ax = sns.countplot(x='quality', data=df)
plt.show()
print(df['quality'].value_counts())
# Out:
# 5    681
# 6    638
# 7    199
# 4     53
# 8     18
# 3     10
# Name: quality, dtype: int64

# %%
# checking relationship

df_corr = df.corr().abs()

# %%
# plotting heatmap to understand corelation betwen columns

plt.figure(figsize=(12,10))
sns.heatmap(df_corr, fmt='.2f',annot=True,annot_kws={'size':14})
plt.show()

# %% [raw]
# From the above heatmap, the relation between two variable is not highly corelated to each other

# %%
# Printing the corelation values of independent variables with target variable in sorted form

df_corr['quality'].sort_values(ascending=False)
# Out:
# quality                 1.000000
# alcohol                 0.476166
# volatile acidity        0.390558
# sulphates               0.251397
# citric acid             0.226373
# total sulfur dioxide    0.185100
# density                 0.174919
# chlorides               0.128907
# fixed acidity           0.124052
# pH                      0.057731
# free sulfur dioxide     0.050656
# residual sugar          0.013732
# Name: quality, dtype: float64

# %% [markdown]
# Almost all independent variables are having less corelation with target variable quantity

# %%
df.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')

# %%
# let's see how data is distributed for every column

plt.figure(figsize=(20,25), facecolor='lightyellow')
plotnumber = 1

for column in df:
    if plotnumber <= 12:
        ax = plt.subplot(3,4,plotnumber)
        sns.distplot(df[column])
        plt.xlabel(column, fontsize=20)
    plotnumber += 1
plt.show()

# %% [markdown]
# We can see skewness in data for mutiple columns

# %% [markdown]
# # Data Preprocessing

# %%
# Separating features and label before removing skewness

x = df.drop('quality',axis=1)
x
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
y=df['quality']

# %%
y.unique()
# Out:
# array([5, 6, 7, 4, 8, 3], dtype=int64)

# %%
# Setting an arbitrary cutoff for dependent variable (wine quality) at e.g. 7 or higher getting classified as 'good/1'
# and the remainder as 'not good/0'.

y = df['quality'].apply(lambda y_value:1 if y_value>=7 else 0)
y
# Out:
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 1594    0
# 1595    0
# 1596    0
# 1597    0
# 1598    0
# Name: quality, Length: 1599, dtype: int64

# %%
print(y.value_counts())
# Out:
# 0    1382
# 1     217
# Name: quality, dtype: int64

# %%
from collections import Counter
Counter(y)
# Out:
# Counter({0: 1382, 1: 217})

# %%
# oversampling


from imblearn.over_sampling import SMOTE
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [61], in <cell line: 4>()
#       1 # oversampling
# ----> 4 from imblearn.over_sampling import SMOTE
#
# ModuleNotFoundError: No module named 'imblearn'

# %%
import six
import joblib
import sys
sys.modules['sklearn.externals.six']=six
sys.modules['sklearn.externals.joblib']=joblib

# %%
os=SMOTE()
x_res,y_res=os.fit_sample(x, y)
